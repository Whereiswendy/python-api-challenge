# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path
from IPython.display import HTML
import folium
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
from branca.element import Template, MacroElement
import json
import requests

# Import API key
from api_keys import geoapify_key

# %%
pwd
# Out:
# 'c:\\Users\\wware\\Desktop\\UWA Bootcamp\\Challenges\\python-api-challenge\\VacationPy'

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("Resources/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     fortaleza  -3.7227  -38.5247     28.07        78           0
# 1        1        neiafu -18.6500 -173.9833     27.38        54          40
# 2        2  invercargill -46.4000  168.3500     10.57        99          92
# 3        3  longyearbyen  78.2186   15.6401     -0.09        80          75
# 4        4       stanley  54.8680   -1.6985     11.40        89           0
#
#    Wind Speed Country        Date
# 0        2.57      BR  1715472798
# 1        5.66      TO  1715472799
# 2        1.79      NZ  1715472800
# 3        4.63      SJ  1715472801
# 4        2.06      GB  1715472801

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Get unique cities and assign a color to each - with hover data in this code
unique_cities = city_data_df['City'].unique()
colors = plt.cm.tab20(np.linspace(0, 1, len(unique_cities)))  # Using tab20 colormap
color_map = {city: mcolors.to_hex(color) for city, color in zip(unique_cities, colors)}

# Calculate mean latitude and longitude to center the map
mean_lat = city_data_df['Lat'].mean()
mean_lng = city_data_df['Lng'].mean()

# Create the Folium map with specified bounds
map = folium.Map(location=[mean_lat, mean_lng], zoom_start=2, tiles='CartoDB positron',
                 min_zoom=2, max_bounds=True)

# Add markers to the map without marker lines
for index, row in city_data_df.iterrows():
    popup_text = f"{row['City']}, {row['Country']}<br>Humidity: {row['Humidity']}"
    folium.CircleMarker(
        location=[row['Lat'], row['Lng']],
        radius=row['Humidity'] / 15,  # Adjust radius if needed
        color="none",  # This removes the stroke from the circle
        fill=True,
        fill_color=color_map[row['City']],
        fill_opacity=0.8,  # Set transparency level
        popup=folium.Popup(popup_text, max_width=200, sticky=True)  # Popup acts like hover
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b247d0a53681a6850c0e3f23ab4477ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b247d0a53681a6850c0e3f23ab4477ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b247d0a53681a6850c0e3f23ab4477ba = L.map(
#                 &quot;map_b247d0a53681a6850c0e3f23ab4477ba&quot;,
#                 {
#                     center: [19.825993162393164, 15.849739999999999],
#                     crs: L.CRS.EPSG3857,
#                     maxBounds: [[-90, -180], [90, 180]],
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1c5efe089e85c395d1156cfd40edc3e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d1c5efe089e85c395d1156cfd40edc3e.addTo(map_b247d0a53681a6850c0e3f23ab4477ba);
#
#
#             var circle_marker_bbc22a361bfe3bd0f9a73d10d801bdad = L.circleMarker(
#                 [-3.7227, -38.5247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;none&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b247d0a53681a6850c0e3f23ab4477ba);
#
#
#         var popup_17a2a042cefb07e0b66c6f7e8baf23c9 = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: 200});
#
#
#
#                 var html_26befbe941c0abd8917264bc7996bc9b = $(`&lt;div id=&quot;html_26befbe941c0abd8917264bc7996bc9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;fortaleza, BR&lt;br&gt;Humidity: 78&lt;/div&gt;`)[0];
#                 popup_17a2a042cefb07e0b66c6f7e8baf23c9.setContent(html_26befbe941c0abd8917264bc7996bc9b);
#
#
#
#         circle_marker_bbc22a361bfe3bd0f9a73d10d801bdad.bindPopup(popup_17a2a042cefb07e0b66c6f7e8baf23c9)
#         ;
#
#
#
#
#             var circle_marker_b1929dcf3ce46eb64b4f2f733e423381 = L.circleMarker(
#                 [-18.65, -173.9833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;none&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b247d0a53681a6850c0e3f23ab4477ba);
#
#
#         var popup_0bdfd2778ff7ace3ce4a8a557fa1bfbc = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: 200});
#
#
#
#                 var html_95d2d36e193ddc98bb60750ffe314869 = $(`&lt;div id=&quot;html_95d2d36e193ddc98bb60750ffe314869&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;neiafu, TO&lt;br&gt;Humidity: 54&lt;/div&gt;`)[0];
#                 popup_0bdfd2778ff7ace3ce4a8a557fa1bfbc.setContent(html_95d2d36e193ddc98bb60750ffe314869);
#
#
#
#         circle_marker_b1929dcf3ce46eb64b4f2f733e423381.bindPopup(popup_0bdfd2778ff7ace3ce4a8a557fa1bfbc)
#         ;
#
#
#
#
#             var circle_marker_ee27f12afb43d3e7e2d5f3ab17552eb3 = L.circleMarker(
#                 [-46.4, 168.35],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;none&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b247d0a53681a6850c0e3f23ab4477ba);
#
#
#         var popup_fa1decf8f48dcda270097772928604e2 = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: 200});
#
#
#
#                 var html_c6b916498e0384a63fc25e2d1ac7baed = $(`&lt;div id=&quot;html_c6b916498e0384a63fc25e2d1ac7baed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;invercargill, NZ&lt;br&gt;Humidity: 99&lt;/div&gt;`)[0];
#                 popup_fa1decf8f48dcda270097772928604e2.setContent(html_c6b916498e0384a63fc25e2d1ac7baed);
#
#
#
#         circle_marker_ee27f12afb43d3e7e2d5f3ab17552eb3.bindPopup(popup_fa1decf8f48dcda27009777292

# %%
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size="Humidity",
    scale=1,
    color="City",
    #legend=False, # Hide the legend
    alpha=0.8
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     fortaleza  -3.7227  -38.5247     28.07        78           0
# 1        1        neiafu -18.6500 -173.9833     27.38        54          40
# 2        2  invercargill -46.4000  168.3500     10.57        99          92
# 3        3  longyearbyen  78.2186   15.6401     -0.09        80          75
# 4        4       stanley  54.8680   -1.6985     11.40        89           0
#
#    Wind Speed Country        Date
# 0        2.57      BR  1715472798
# 1        5.66      TO  1715472799
# 2        1.79      NZ  1715472800
# 3        4.63      SJ  1715472801
# 4        2.06      GB  1715472801

# %%
# Narrow down cities that fit criteria
# Filter the DataFrame based on the conditions
filtered_cities_df = city_data_df[
    (city_data_df['Max Temp'] > 21) & 
    (city_data_df['Max Temp'] < 27) & 
    (city_data_df['Wind Speed'] < 4.5) & 
    (city_data_df['Cloudiness'] == 0)
]

# Display the filtered DataFrame
print(filtered_cities_df)
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 127      127           robore -18.3333  -59.7500     26.80        45
# 188      188     poplar bluff  36.7570  -90.3929     25.88        38
# 212      212        andalusia  31.3085  -86.4833     23.97        58
# 226      226  remire-montjoly   4.9167  -52.2667     26.02        94
# 254      254       monticello  45.3055  -93.7941     25.18        23
# 307      307       pocahontas  36.2615  -90.9712     25.95        33
# 309      309           keokuk  40.3973  -91.3849     23.29        33
# 371      371           sparta  43.9441  -90.8129     21.09        30
# 390      390     saint-pierre -21.3393   55.4781     21.82        60
# 414      414           maxixe -23.8597   35.3472     21.97        88
# 432      432          emporia  38.4039  -96.1817     26.11        34
# 444      444         holualoa  19.6228 -155.9522     26.25        74
# 463      463             tete -16.1564   33.5867     24.05        57
# 471      471        dalbandin  28.8947   64.4101     23.03        17
# 542      542        inhambane -23.8650   35.3833     22.65        85
# 554      554    pacific grove  36.6177 -121.9166     25.36        77
#
#      Cloudiness  Wind Speed Country        Date
# 127           0        2.01      BO  1715472905
# 188           0        2.06      US  1715472962
# 212           0        2.57      US  1715472935
# 226           0        0.00      GF  1715472994
# 254           0        1.54      US  1715473017
# 307           0        3.60      US  1715473059
# 309           0        3.60      US  1715473060
# 371           0        0.00      US  1715473114
# 390           0        4.12      RE  1715473132
# 414           0        0.66      MZ  1715473152
# 432           0        2.06      US  1715473167
# 444           0        3.09      US  1715473178
# 463           0        0.00      MZ  1715473195
# 471           0        2.79      PK  1715473201
# 542           0        1.04      MZ  1715473260
# 554           0        2.68      US  1715473270

# %%
# Drop any results with ull values
# Drop any rows with null values in the columns of interest
filtered_cities_df.dropna(subset=['Max Temp', 'Wind Speed', 'Cloudiness'], inplace=True)

# Display the cleaned DataFrame to confirm removal of null values
print(filtered_cities_df)
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 127      127           robore -18.3333  -59.7500     26.80        45
# 188      188     poplar bluff  36.7570  -90.3929     25.88        38
# 212      212        andalusia  31.3085  -86.4833     23.97        58
# 226      226  remire-montjoly   4.9167  -52.2667     26.02        94
# 254      254       monticello  45.3055  -93.7941     25.18        23
# 307      307       pocahontas  36.2615  -90.9712     25.95        33
# 309      309           keokuk  40.3973  -91.3849     23.29        33
# 371      371           sparta  43.9441  -90.8129     21.09        30
# 390      390     saint-pierre -21.3393   55.4781     21.82        60
# 414      414           maxixe -23.8597   35.3472     21.97        88
# 432      432          emporia  38.4039  -96.1817     26.11        34
# 444      444         holualoa  19.6228 -155.9522     26.25        74
# 463      463             tete -16.1564   33.5867     24.05        57
# 471      471        dalbandin  28.8947   64.4101     23.03        17
# 542      542        inhambane -23.8650   35.3833     22.65        85
# 554      554    pacific grove  36.6177 -121.9166     25.36        77
#
#      Cloudiness  Wind Speed Country        Date
# 127           0        2.01      BO  1715472905
# 188           0        2.06      US  1715472962
# 212           0        2.57      US  1715472935
# 226           0        0.00      GF  1715472994
# 254           0        1.54      US  1715473017
# 307           0        3.60      US  1715473059
# 309           0        3.60      US  1715473060
# 371           0        0.00      US  1715473114
# 390           0        4.12      RE  1715473132
# 414           0        0.66      MZ  1715473152
# 432           0        2.06      US  1715473167
# 444           0        3.09      US  1715473178
# 463           0        0.00      MZ  1715473195
# 471           0        2.79      PK  1715473201
# 542           0        1.04      MZ  1715473260
# 554           0        2.68      US  1715473270
# C:\Users\wware\AppData\Local\Temp\ipykernel_40528\1873084615.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_cities_df.dropna(subset=['Max Temp', 'Wind Speed', 'Cloudiness'], inplace=True)

# %%
# Display sample data
filtered_cities_df.head(10)
# Out:
#      City_ID             City      Lat      Lng  Max Temp  Humidity  \
# 127      127           robore -18.3333 -59.7500     26.80        45
# 188      188     poplar bluff  36.7570 -90.3929     25.88        38
# 212      212        andalusia  31.3085 -86.4833     23.97        58
# 226      226  remire-montjoly   4.9167 -52.2667     26.02        94
# 254      254       monticello  45.3055 -93.7941     25.18        23
# 307      307       pocahontas  36.2615 -90.9712     25.95        33
# 309      309           keokuk  40.3973 -91.3849     23.29        33
# 371      371           sparta  43.9441 -90.8129     21.09        30
# 390      390     saint-pierre -21.3393  55.4781     21.82        60
# 414      414           maxixe -23.8597  35.3472     21.97        88
#
#      Cloudiness  Wind Speed Country        Date
# 127           0        2.01      BO  1715472905
# 188           0        2.06      US  1715472962
# 212           0        2.57      US  1715472935
# 226           0        0.00      GF  1715472994
# 254           0        1.54      US  1715473017
# 307           0        3.60      US  1715473059
# 309           0        3.60      US  1715473060
# 371           0        0.00      US  1715473114
# 390           0        4.12      RE  1715473132
# 414           0        0.66      MZ  1715473152

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# Create a new DataFrame with selected columns
hotel_df = filtered_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Display the initial data
print(hotel_df.head())
# Out:
#                 City Country      Lat      Lng  Humidity
# 127           robore      BO -18.3333 -59.7500        45
# 188     poplar bluff      US  36.7570 -90.3929        38
# 212        andalusia      US  31.3085 -86.4833        58
# 226  remire-montjoly      GF   4.9167 -52.2667        94
# 254       monticello      US  45.3055 -93.7941        23

# %%
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# Add an empty column for "Hotel Name"
hotel_df['Hotel Name'] = ""

# Display the DataFrame to confirm the new column
print(hotel_df.head())
# Out:
#                 City Country      Lat      Lng  Humidity Hotel Name
# 127           robore      BO -18.3333 -59.7500        45
# 188     poplar bluff      US  36.7570 -90.3929        38
# 212        andalusia      US  31.3085 -86.4833        58
# 226  remire-montjoly      GF   4.9167 -52.2667        94
# 254       monticello      US  45.3055 -93.7941        23

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
pwd
# Out:
# 'c:\\Users\\wware\\Desktop\\UWA Bootcamp\\Challenges\\python-api-challenge\\VacationPy'

# %%
import requests
from api_keys import geoapify_key

url = 'https://api.geoapify.com/v2/places' 
params = {
    'categories': 'accommodation.hotel',
    'filter': 'circle:-122.4194,37.7749,10000',
    'limit': 1,
    'apiKey': geoapify_key
}

response = requests.get(url, params=params)
response.json()  # This will print the response from the API
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Hotel Kabuki',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'California',
#     'city': 'San Francisco',
#     'postcode': '94115',
#     'district': 'Western Addition',
#     'street': 'Laguna Street',
#     'housenumber': '1625',
#     'lon': -122.42860829440426,
#     'lat': 37.7854004,
#     'state_code': 'CA',
#     'formatted': 'Hotel Kabuki, 1625 Laguna Street, San Francisco, CA 94115, United States of America',
#     'address_line1': 'Hotel Kabuki',
#     'address_line2': '1625 Laguna Street, San Francisco, CA 94115, United States of America',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation',
#      'internet_access'],
#     'details': ['details',
#      'details.contact',
#      'details.facilities',
#      'details.wiki_and_media'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database License',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Hotel Kabuki',
#       'email': 'kabukifrontdesk@jdvhotels.com',
#       'phone': '+1-415-922-3200',
#       'osm_id': 1160773277,
#       'tourism': 'hotel',
#       'website': 'https://www.jdvhotels.com/hotels/california/san-francisco/hotel-kabuki',
#       'building': 'yes',
#       'operator': 'JDV',
#       'osm_type': 'w',
#       'addr:city': 'San Francisco',
#       'addr:street': 'Post Street',
#       'addr:country': 'US',
#       'addr:postcode': 94115,
#       'opening_hours': '24/7',
#       'internet_access': 'wlan',
#       'addr:housenumber': 1625,
#       'wikimedia_commons': 'Category:Hotel Kabuki (San Francisco)'}},
#     'website': 'https://www.jdvhotels.com/hotels/california/san-francisco/hotel-kabuki',
#     'opening_hours': '24/7',
#     'operator': 'JDV',
#     'contact': {'phone': '+1-415-922-3200',
#      'email': 'kabukifrontdesk@jdvhotels.com'},
#     'facilities': {'internet_access': True},
#     'wiki_and_media': {'wikimedia_commons': 'Category:Hotel Kabuki (San Francisco)'},
#     'place_id': '51aed07b516e9b5ec0599807140088e44240f00102f9019dfe2f450000000092030c486f74656c204b6162756b69'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.42860829440426, 37.78540039995204]}}]}

# %%
# Set radius in meters for the hotel search around the city coordinates
radius = 10000  # 10,000 meters

print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from the DataFrame
    lat, lng = row['Lat'], row['Lng']

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params = {
        'categories': 'accommodation.hotel',
        'filter': f'circle:{lng},{lat},{radius}',
        'limit': 1,
        'apiKey': geoapify_key
    }

    # Set base URL for the Geoapify Places API
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    hotels_response = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels_response["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{row['City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data to confirm updates
print(hotel_df.head())
# Out:
# Starting hotel search
# robore - nearest hotel: La Casona de Don Pepe
# poplar bluff - nearest hotel: Holiday Inn
# andalusia - nearest hotel: Best Western
# remire-montjoly - nearest hotel: Central Hôtel
# monticello - nearest hotel: Best Western Plus Chelsea Hotel
# pocahontas - nearest hotel: No hotel found
# keokuk - nearest hotel: Quality Inn & Suites
# sparta - nearest hotel: Country Inn & Suites
# saint-pierre - nearest hotel: La Villa Delisle
# maxixe - nearest hotel: Casa Jensen
# emporia - nearest hotel: Budget Host Inn Emporia
# holualoa - nearest hotel: Kona Seaside Hotel
# tete - nearest hotel: Tete Ferry Sun
# dalbandin - nearest hotel: SF Al-dawood Restaurant
# inhambane - nearest hotel: Casa Jensen
# pacific grove - nearest hotel: InterContinental The Clement Monterey Hotel
#                 City Country      Lat      Lng  Humidity  \
# 127           robore      BO -18.3333 -59.7500        45
# 188     poplar bluff      US  36.7570 -90.3929        38
# 212        andalusia      US  31.3085 -86.4833        58
# 226  remire-montjoly      GF   4.9167 -52.2667        94
# 254       monticello      US  45.3055 -93.7941        23
#
#                           Hotel Name
# 127            La Casona de Don Pepe
# 188                      Holiday Inn
# 212                     Best Western
# 226                    Central Hôtel
# 254  Best Western Plus Chelsea Hotel

# %%
hotels=hotel_df['Hotel Name'].nunique()
hotels
# Out:
# 15

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
import hvplot.pandas  # Ensure hvplot is imported if not already

# Filter out rows where 'No hotel found'
filtered_hotel_df = hotel_df[hotel_df['Hotel Name'] != 'No hotel found']

# Configure the map plot using filtered DataFrame with additional hover information
map_plot = filtered_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    size='Humidity',
    scale=1,
    color='City',
    alpha=0.8,
    hover_cols=['Hotel Name', 'Country']  # Additional columns to display in hover tooltip
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
